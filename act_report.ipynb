# %% [markdown]
# # WeRateDogs twitter archive data insights and visualizations

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The above bar chart is a visual representation of the source or device that the users tweeted from. The value count for each source is represented as:
#
# - Twitter for iPhone 2001
# - Twitter Web Client 30
# - TweetDeck 10

# %% [markdown]
# ## Analysis of the various stages
#
# ![Classification of dogs by stages.png](attachment:image.png)
# The above bar chart is a visual representation of the various dog stages. The tabular representation of the various stages shows that 1723 dogs were not classified because the owner did not specify.
#
# - None   1723
# - pupper 221
# - doggo 65
# - puppo 24
# - floofer 8

# %% [markdown]
# ## Analysis of the breed of dogs
#
# The value count of the dog_breed column shows that the breed of 539 dogs was not recorded. The golden retriver breed has the highest count of 146, the labrador retriever breed has a count of 94, the Pembroke breed has a count of 88, pugs have a count of 57, while the breeds with the least counts are EntleBucher, Japanese_spaniel, Clumber, Groenendael, Silky terrier, Standard schnauzer, and Scotch terrier.

# %% [markdown]
# ## Average retweet count for each dog breed
#
# An insight into the types of breed that got the highest and lowest retweets reveals that the top three breed with highest retweet counts are Standard poodle, Afghan hound, and English springer. The breeds with the lowest amount of retweets are Ibizan hound, Groenendael, Brabancon griffon.

# %% [markdown]
# ## Average favorite count for each dog breed
#
# An insight into the types of breed that were most liked and least liked reveals that the breeds favorited the most are Saluki, French bulldog, and Black and tan coonhound, while the breeds favorited the least are Japanese spaniel, Ibizan hound, Brabancon griffon.

# %% [markdown]
# ## Average ratings for each dog breed
#
# An insight into the types of breed that received the highest and lowest ratings reveals that the breeds with the highest rating averages are Clumber, Soft coated wheaten terrier, and West highland white terrier, while the breeds with the lowest rating averages are Norwich terrier, Scotch terrier, and Japanese spaniel. However, tweets with unspecified breed also got an average rating of 13.64, which is pretty high.

# %% [markdown]
# ## Analysis of WeRateDogs monthly data
#
# ![Monthly trend of tweets.png](attachment:image.png)
#
# The line graph above shows the distribution of tweets over the months. This plot reveals that the month where people tweet the most about their dogs is December while the month people tweet the least about their dogs is August.

# %%
! jupyter nbconvert --to html act_report.ipynb
# Out:
# [NbConvertApp] Converting notebook act_report.ipynb to html
# [NbConvertApp] Writing 325324 bytes to act_report.html
